# %% [markdown]
# # Example 1: varying ratios

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve().parents[2]
sys.path.append(str(project_root))
from LNPBO.data.dataset import Dataset
from LNPBO.optimization.optimizer import Optimizer
from LNPBO.space.formulation import FormulationSpace

# %%
# Load dataset
dataset = Dataset.from_lnpdb_csv("example1.csv")
print("dataset loaded")
# Out:
# dataset loaded

# %%
# Encode dataset
encoded_dataset = dataset.encode_dataset(
    encoding_csv_path="example1_encodings.csv",
)
print("dataset encoded")
# Out:
# dataset encoded

# %%
# Build FormulationSpace for BO
space = FormulationSpace.from_dataset(encoded_dataset)
print("space built")
# Out:
# space built

# %%
# Initialize Optimizer
optimizer = Optimizer(space=space, type="UCB", kappa=5.0, alpha=1e-6, random_seed=42, batch_size=24)
print("optimizer initialized")
# Out:
# optimizer initialized

# %%
# Perform first round of BO suggestions
round1_suggestions = optimizer.suggest(output_csv="example1_round1.csv")
print("round 1 suggested")
# Out:
# /media/andersonxps/wd_12tb/LNPBO/optimization/bayesopt.py:100: UserWarning: Non-float parameters are experimental and may not work as expected. Exercise caution when using them and please report any issues you encounter.
#   optimizer = BayesianOptimization(
# /home/andersonxps/anaconda3/envs/lnpbo/lib/python3.11/site-packages/bayes_opt/bayesian_optimization.py:290: UserWarning: You're attempting to register an np.ndarray. In previous versions, the optimizer internally sorted parameters by key and expected any registered array to respect this order. In the current and any future version the order as given by the pbounds dictionary will be used. If you wish to retain sorted parameters, please manually sort your pbounds dictionary before constructing the optimizer.
#   warn(msg, stacklevel=1)
# | 1         | 674642.0  | 1.0       | 0.|0.|0.  |
# | 2         | 446054.0  | 1.0       | 0.|0.|0.  |
# | 3         | 363328.0  | 1.0       | 0.|0.|0.  |
# | 4         | 460485.0  | 1.0       | 0.|0.|0.  |
# | 5         | 345696.0  | 1.0       | 0.|0.|0.  |
# | 6         | 483233.0  | 1.0       | 0.|0.|0.  |
# | 7         | 406118.0  | 1.0       | 0.|0.|0.  |
# | 8         | 692413.0  | 1.0       | 0.|0.|0.  |
# | 9         | 373309.0  | 1.0       | 0.|0.|0.  |
# | 10        | 717351.0  | 1.0       | 0.|0.|0.  |
# | 11        | 985895.0  | 1.0       | 0.|0.|0.  |
# | 12        | 417998.0  | 1.0       | 0.|0.|0.  |
# | 13        | 415444.0  | 1.0       | 0.|0.|0.  |
# | 14        | 671095.0  | 1.0       | 0.|0.|0.  |
# | 15        | 910324.0  | 1.0       | 0.|0.|0.  |
# | 16        | 526785.0  | 1.0       | 0.|0.|0.  |
# | 17        | 591219.0  | 1.0       | 0.|0.|0.  |
# | 18        | 486993.0  | 1.0       | 0.|0.|0.  |
# | 19        | 681368.0  | 0.0       | 0.|0.|0.  |
# | 20        | 341142.0  | 0.0       | 0.|0.|0.  |
# | 21        | 315768.0  | 0.0       | 0.|0.|0.  |
# | 22        | 320450.0  | 0.0       | 0.|0.|0.  |
# | 23        | 287156.0  | 0.0       | 0.|0.|0.  |
# | 24        | 459907.0  | 0.0       | 0.|0.|0.  |
# | 25        | 240002.0  | 0.0       | 0.|0.|0.  |
# | 26        | 555525.0  | 0.0       | 0.|0.|0.  |
# | 27        | 223141.0  | 0.0       | 0.|0.|0.  |
# | 28        | 552720.0  | 0.0       | 0.|0.|0.  |
# | 29        | 729399.0  | 0.0       | 0.|0.|0.  |
# | 30        | 339410.0  | 0.0       | 0.|0.|0.  |
# | 31        | 353710.0  | 0.0       | 0.|0.|0.  |
# | 32        | 896885.0  | 0.0       | 0.|0.|0.  |
# | 33        | 623033.0  | 0.0       | 0.|0.|0.  |
# | 34        | 666168.0  | 0.0       | 0.|0.|0.  |
# | 35        | 324895.0  | 0.0       | 0.|0.|0.  |
# | 36        | 160425.0  | 0.0       | 0.|0.|0.  |
# Selecting LNP formulations: 100%|█████████████████████████| 24/24 [00:23<00:00,  1.04it/s]
# Suggested formulations written to example1_round1.csv
# round 1 suggested
